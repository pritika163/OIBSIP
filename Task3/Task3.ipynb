# %% [markdown]
# ## Oasis Infobyte Internship
# ## Data Science
# ## Name: Pritika Bhar

# %%
import pandas as pd
from pandas import DataFrame

# %%
df=pd.read_csv('CarPrice.csv') #reading the dataset

# %%
df.head()  #displaying the first 5 rows of dataset
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.shape  #displaying the number of rows and columns in the datset
# Out:
# (205, 26)

# %%
df.info()   #displaying the overall information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.columns  #displaying all the columns of dataset
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.isnull().sum()  #checks for missing values
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.fueltype.unique()  #displays unique values for fueltype
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df.aspiration.unique()  #displays unique values for aspiration
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
df.enginelocation.unique()  #displays unique values for enginelocation
# Out:
# array(['front', 'rear'], dtype=object)

# %%
df.doornumber.unique()  #displays unique values for doornumber
# Out:
# array(['two', 'four'], dtype=object)

# %%
df.carbody.unique()  #displays unique values for carbody
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
df.drivewheel.unique()  #displays unique values for drivewheel
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df.enginetype.unique()  #displays unique values for enginetype
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
df.cylindernumber.unique()  #displays unique values for cylindernumber
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
df.fuelsystem.unique()  #displays unique values for fuelsystem
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
df1=df

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l=LabelEncoder()

# %%
cols=['fueltype','aspiration','doornumber','carbody','drivewheel', 'enginelocation','enginetype','cylindernumber','fuelsystem']
df1[cols]=df1[cols].apply(LabelEncoder().fit_transform)
df1.head()
# Out:
#    car_ID  symboling                   CarName  fueltype  aspiration  \
# 0       1          3        alfa-romero giulia         1           0
# 1       2          3       alfa-romero stelvio         1           0
# 2       3          1  alfa-romero Quadrifoglio         1           0
# 3       4          2               audi 100 ls         1           0
# 4       5          2                audi 100ls         1           0
#
#    doornumber  carbody  drivewheel  enginelocation  wheelbase  ...  \
# 0           1        0           2               0       88.6  ...
# 1           1        0           2               0       88.6  ...
# 2           1        2           2               0       94.5  ...
# 3           0        3           1               0       99.8  ...
# 4           0        3           0               0       99.4  ...
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# ...

# %%
X=df1.drop(['CarName','price','car_ID'],axis=1)  #the independent variables
Y=df1['price']  #the dependent variable

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=10) #splitting the data into train and test set

# %%
X_train.sort_index()  #displaying independent train set
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            3         1           0           1        0           2
# 3            2         1           0           0        3           1
# 4            2         1           0           0        3           0
# 8            1         1           1           0        3           1
# 9            0         1           1           1        2           0
# ..         ...       ...         ...         ...      ...         ...
# 198         -2         1           1           0        3           2
# 199         -1         1           1           0        4           2
# 200         -1         1           0           0        3           2
# 201         -1         1           1           0        3           2
# 202         -1         1           0           0        3           2
#
#      enginelocation  wheelbase  carlength  carwidth  ...  cylindernumber  \
# ...

# %%
X_test.sort_index()  #displaying independent test set
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 1            3         1           0           1        0           2
# 2            1         1           0           1        2           2
# 5            2         1           0           1        3           1
# 6            1         1           0           0        3           1
# 7            1         1           0           0        4           1
# ..         ...       ...         ...         ...      ...         ...
# 178          3         1           0           1        2           2
# 190          3         1           0           1        2           1
# 195         -1         1           0           0        4           2
# 203         -1         0           1           0        3           2
# 204         -1         1           1           0        3           2
#
#      enginelocation  wheelbase  carlength  carwidth  ...  cylindernumber  \
# ...

# %%
Y_train.sort_index()  #displaying dependent train set
# Out:
# 0      13495.000
# 3      13950.000
# 4      17450.000
# 8      23875.000
# 9      17859.167
#          ...
# 198    18420.000
# 199    18950.000
# 200    16845.000
# 201    19045.000
# 202    21485.000
# Name: price, Length: 143, dtype: float64

# %%
Y_test.sort_index()  #displaying dependent test set
# Out:
# 1      16500.0
# 2      16500.0
# 5      15250.0
# 6      17710.0
# 7      18920.0
#         ...
# 178    16558.0
# 190     9980.0
# 195    13415.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 62, dtype: float64

# %%
r=linear_model.LinearRegression()
r.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
re=r.predict(X_test)  #predicting the price

# %%
re
# Out:
# array([ 9631.30089681, 19212.39186745, 12391.68585347,  9464.05889875,
#        50425.33907756, 11109.96611828,  6583.82648967, 13102.59559913,
#         5423.35065742, 21774.00572264, 13046.53567002, 10015.35486969,
#         9720.46669369, 18346.44719658, 30668.47970865, 24675.21934093,
#        10404.28615637, 18176.82015024, 11135.74439463, 20075.26989817,
#         8769.26458893, 11417.42790394, 13592.74752698, 21787.90108145,
#        17637.39704701, 18500.59224296, 12235.86014771,  6806.52462908,
#        10782.7042345 , 24527.06569964,  6438.44491281,  6789.67532789,
#         6061.61778985, 12373.04905398, 25298.89902887, 23995.41075474,
#         9213.11261137, 24943.01530505,  9915.00288588,  6530.76663848,
#         9960.09011481,  7902.10016563,  7193.90225329, 34384.29849041,
#        33385.98846713,  5902.72952503, 15173.21910547, 18271.45265519,
#         9088.26588266, 14989.5106414 , 10013.46175844, 16683.1888254 ,
# ...

# %%
print(DataFrame({"Predicted price":re}))
# Out:
#     Predicted price
# 0       9631.300897
# 1      19212.391867
# 2      12391.685853
# 3       9464.058899
# 4      50425.339078
# ..              ...
# 57      8195.203343
# 58     18166.255261
# 59     29607.387732
# 60     10566.319150
# 61      6803.772368
#
# [62 rows x 1 columns]

# %%
r.score(X_test,Y_test)  #gives the accuracy score of model
# Out:
# 0.7586403435042961

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(Y_test,re)
plt.show()
